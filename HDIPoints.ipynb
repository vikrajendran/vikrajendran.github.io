# %%
#import packages
import pandas as pd
import numpy as np

# %%
#load datasets
df1 = pd.read_csv('HDIPercentD.csv')

df2 = pd.read_csv('PopulationData1.csv')

# %%
#merge datasets using outer to check for any matching errors
df = pd.merge(df1,df2, on = 'Alpha-3 code', how = 'outer')

# %%
#check for matching errors
print(df.to_string())
# Out:
#                        Country Name  Mens Points  Womens Points Alpha-3 code  Percentage Difference  HDI rank  Value                                               Country      YR2021
# 0                           Albania      1361.81        1346.01          ALB               1.160221      67.0  0.796                                               Albania     2811666
# 1                           Algeria      1480.59        1288.27          DZA              12.989416      91.0  0.745                                               Algeria    44616626
# 2                           Andorra      1028.70         751.46          AND              26.950520      40.0  0.858                                               Andorra       77354
# 3                            Angola      1149.08        1041.91          AGO               9.326592     148.0  0.586                                                Angola    33933611
# ...

# %%
#rename columns
df.columns = ['Population' if x=='YR2021' else x for x in df.columns]
df.columns = ['HDI' if x=='Value' else x for x in df.columns]

# %%
#remove countries without data
df = df.dropna()

# %%
#check shape
df.shape
# Out:
# (163, 9)

# %%
#download csv
df.to_csv('HDIPoints.csv')

# %%
#format data for regression
X = df['Womens Points'].values[:, np.newaxis]

y = df['HDI'].values

# %%
#perform regression
import statsmodels.api as sm

x2 = sm.add_constant(X)

model = sm.OLS(y, x2).fit()
predictions = model.predict(x2)




model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.342
# Model:                            OLS   Adj. R-squared:                  0.338
# Method:                 Least Squares   F-statistic:                     83.67
# Date:                Wed, 14 Dec 2022   Prob (F-statistic):           2.48e-16
# Time:                        09:56:47   Log-Likelihood:                 115.81
# No. Observations:                 163   AIC:                            -227.6
# Df Residuals:                     161   BIC:                            -221.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.4001      0.037     10.734      0.000       0.326       0.474
# ...
