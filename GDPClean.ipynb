# %%
#import pandas and world bank API
import wbgapi as wb
import pandas as pd

# %%
#load data from world bank API
df = wb.data.DataFrame('NY.GDP.PCAP.PP.CD', labels = True)

# %%
df.head()
# Out:
#                        Country  YR1960  YR1961  YR1962  YR1963  YR1964  \
# economy
# ZWE                   Zimbabwe     NaN     NaN     NaN     NaN     NaN
# ZMB                     Zambia     NaN     NaN     NaN     NaN     NaN
# YEM                Yemen, Rep.     NaN     NaN     NaN     NaN     NaN
# PSE         West Bank and Gaza     NaN     NaN     NaN     NaN     NaN
# VIR      Virgin Islands (U.S.)     NaN     NaN     NaN     NaN     NaN
#
#          YR1965  YR1966  YR1967  YR1968  ...       YR2012       YR2013  \
# economy                                  ...
# ZWE         NaN     NaN     NaN     NaN  ...  2375.927006  2560.773267
# ZMB         NaN     NaN     NaN     NaN  ...  3422.619937  3578.847055
# YEM         NaN     NaN     NaN     NaN  ...  3491.204610  3688.519409
# PSE         NaN     NaN     NaN     NaN  ...  5255.825609  5371.687100
# VIR         NaN     NaN     NaN     NaN  ...          NaN          NaN
#
# ...

# %%
#remove unwanted columns
df = df[['Country', 'YR2020']]

# %%
df.head()
# Out:
#                        Country       YR2020
# economy
# ZWE                   Zimbabwe  2251.455674
# ZMB                     Zambia  3457.328102
# YEM                Yemen, Rep.          NaN
# PSE         West Bank and Gaza  5698.412057
# VIR      Virgin Islands (U.S.)          NaN

# %%
#remove countries without data
df = df.dropna()

# %%
df.head()
# Out:
#                     Country        YR2020
# economy
# ZWE                Zimbabwe   2251.455674
# ZMB                  Zambia   3457.328102
# PSE      West Bank and Gaza   5698.412057
# VNM                 Vietnam  10904.452146
# VUT                 Vanuatu   3036.116767

# %%
#download csv
df.to_csv('GDPData1.csv')
