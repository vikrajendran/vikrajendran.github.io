# %%
#import world bank API and pandas
import wbgapi as wb
import pandas as pd

# %%
#load data from world bank API
df = wb.data.DataFrame('SP.POP.TOTL', labels = True)

# %%
df.head()
# Out:
#                        Country     YR1960     YR1961     YR1962     YR1963  \
# economy
# ZWE                   Zimbabwe  3776679.0  3905038.0  4039209.0  4178726.0
# ZMB                     Zambia  3070780.0  3164330.0  3260645.0  3360099.0
# YEM                Yemen, Rep.  5315351.0  5393034.0  5473671.0  5556767.0
# PSE         West Bank and Gaza        NaN        NaN        NaN        NaN
# VIR      Virgin Islands (U.S.)    32500.0    34300.0    35000.0    39800.0
#
#             YR1964     YR1965     YR1966     YR1967     YR1968  ...  \
# economy                                                         ...
# ZWE      4322854.0  4471178.0  4623340.0  4779825.0  4941901.0  ...
# ZMB      3463211.0  3570466.0  3681953.0  3797877.0  3918872.0  ...
# YEM      5641598.0  5727745.0  5816241.0  5907873.0  6001858.0  ...
# PSE            NaN        NaN        NaN        NaN        NaN  ...
# VIR        40800.0    43500.0    46200.0    49100.0    55700.0  ...
#
# ...

# %%
#remove unwanted columns
df = df[['Country', 'YR2021']]

# %%
#remove countries without data
df = df.dropna()

# %%
df.head()
# Out:
#                        Country      YR2021
# economy
# ZWE                   Zimbabwe  15092171.0
# ZMB                     Zambia  18920657.0
# YEM                Yemen, Rep.  30490639.0
# PSE         West Bank and Gaza   4922749.0
# VIR      Virgin Islands (U.S.)    105870.0

# %%
#download as csv
df.to_csv('PopulationData1.csv')
